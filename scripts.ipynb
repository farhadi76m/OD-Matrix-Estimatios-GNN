# %%
# !netconvert --sumo-net-file map.net.xml --plain-output-prefix extracted
# Out:
# Success.
# ...

# %%
# !python "C:\Program Files (x86)\Eclipse\Sumo\tools\district\gridDistricts.py" -n map.net.xml -o grids.taz.xml -w 300

# %%
# !sumo-gui.exe -n map.net.xml -a grids.taz.xml
